# %% [markdown]
# # **Implement POS tagging on a text corpus using an NLP library (like NLTK or SpaCy). Analyze the grammatical structure of sentences using syntactic/dependency parsing.**

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = """
Data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processing, scientific visualization, algorithms and systems to extract or extrapolate knowledge from potentially noisy, structured, or unstructured data.[2]

Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3] Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]

Data science is "a concept to unify statistics, data analysis, informatics, and their related methods" to "understand and analyze actual phenomena" with data.[5] It uses techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, information science, and domain knowledge.[6] However, data science is different from computer science and information science. Turing Award winner Jim Gray imagined data science as a "fourth paradigm" of science (empirical, theoretical, computational, and now data-driven) and asserted that "everything about science is changing because of the impact of information technology" and the data deluge.[7][8]"""

# %%
doc=nlp(text)

# %% [markdown]
# #POS tagging

# %%
for token in doc:
    print(f"{token.text:15}  POS: {token.pos_:10}  TAG: {token.tag_:10}  DEP: {token.dep_}  Description: {spacy.explain(token.tag_)}")
# Out:
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Data             POS: NOUN        TAG: NNS         DEP: compound  Description: noun, plural
# science          POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# is               POS: AUX         TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# an               POS: DET         TAG: DT          DEP: det  Description: determiner
# interdisciplinary  POS: NOUN        TAG: NN          DEP: amod  Description: noun, singular or mass
# academic         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# field[1          POS: PROPN       TAG: NNP         DEP: attr  Description: noun, proper singular
# ]                POS: PUNCT       TAG: -RRB-       DEP: attr  Description: right round bracket
# that             POS: PRON        TAG: WDT         DEP: nsubj  Description: wh-determiner
# uses             POS: VERB        TAG: VBZ         DEP: ccomp  Description: verb, 3rd person singular present
# statistics       POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# scientific       POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# computing        POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# scientific       POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# methods          POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# processing       POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# scientific       POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# visualization    POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# algorithms       POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# systems          POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# to               POS: PART        TAG: TO          DEP: aux  Description: infinitival "to"
# extract          POS: VERB        TAG: VB          DEP: xcomp  Description: verb, base form
# or               POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# extrapolate      POS: VERB        TAG: VB          DEP: conj  Description: verb, base form
# knowledge        POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# from             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# potentially      POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# noisy            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# structured       POS: VERB        TAG: VBN         DEP: conj  Description: verb, past participle
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# or               POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# unstructured     POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# data.[2          POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Data             POS: NOUN        TAG: NNS         DEP: compound  Description: noun, plural
# science          POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# also             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# integrates       POS: VERB        TAG: VBZ         DEP: conj  Description: verb, 3rd person singular present
# domain           POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# knowledge        POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# from             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# underlying       POS: VERB        TAG: VBG         DEP: amod  Description: verb, gerund or present participle
# application      POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# domain           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# e.g.             POS: ADV         TAG: RB          DEP: dep  Description: adverb
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# natural          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# sciences         POS: NOUN        TAG: NNS         DEP: appos  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# information      POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# technology       POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# medicine).[3     POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# Data             POS: NOUN        TAG: NNS         DEP: compound  Description: noun, plural
# science          POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# is               POS: AUX         TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# multifaceted     POS: ADJ         TAG: JJ          DEP: acomp  Description: adjective (English), other noun-modifier (Chinese)
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# be               POS: AUX         TAG: VB          DEP: auxpass  Description: verb, base form
# described        POS: VERB        TAG: VBN         DEP: conj  Description: verb, past participle
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# science          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# research         POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# paradigm         POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# research         POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# method           POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# discipline       POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# workflow         POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# profession.[4    POS: NOUN        TAG: NN          DEP: nmod  Description: noun, singular or mass
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Data             POS: NOUN        TAG: NNS         DEP: compound  Description: noun, plural
# science          POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# is               POS: AUX         TAG: VBZ         DEP: conj  Description: verb, 3rd person singular present
# "                POS: PUNCT       TAG: ``          DEP: punct  Description: opening quotation mark
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# concept          POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# to               POS: PART        TAG: TO          DEP: aux  Description: infinitival "to"
# unify            POS: VERB        TAG: VB          DEP: acl  Description: verb, base form
# statistics       POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# data             POS: NOUN        TAG: NNS         DEP: compound  Description: noun, plural
# analysis         POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# informatics      POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# their            POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# related          POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# methods          POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# "                POS: PUNCT       TAG: ''          DEP: punct  Description: closing quotation mark
# to               POS: PART        TAG: TO          DEP: aux  Description: infinitival "to"
# "                POS: PUNCT       TAG: ``          DEP: punct  Description: opening quotation mark
# understand       POS: VERB        TAG: VB          DEP: relcl  Description: verb, base form
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# analyze          POS: VERB        TAG: VB          DEP: conj  Description: verb, base form
# actual           POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# phenomena        POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# "                POS: PUNCT       TAG: ''          DEP: punct  Description: closing quotation mark
# with             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# data.[5          POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# It               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# uses             POS: VERB        TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# techniques       POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# theories         POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# drawn            POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# from             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# many             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# fields           POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# within           POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# context          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# mathematics      POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# statistics       POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# computer         POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# science          POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# information      POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# science          POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# domain           POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# knowledge.[6     POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# However          POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# data             POS: NOUN        TAG: NNS         DEP: compound  Description: noun, plural
# science          POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# is               POS: AUX         TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# different        POS: ADJ         TAG: JJ          DEP: acomp  Description: adjective (English), other noun-modifier (Chinese)
# from             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# computer         POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# science          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# information      POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# science          POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Turing           POS: VERB        TAG: VBG         DEP: amod  Description: verb, gerund or present participle
# Award            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# winner           POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# Jim              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Gray             POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# imagined         POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# data             POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# science          POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# "                POS: PUNCT       TAG: ``          DEP: punct  Description: opening quotation mark
# fourth           POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# paradigm         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# "                POS: PUNCT       TAG: ''          DEP: punct  Description: closing quotation mark
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# science          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# empirical        POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# theoretical      POS: ADJ         TAG: JJ          DEP: conj  Description: adjective (English), other noun-modifier (Chinese)
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# computational    POS: ADJ         TAG: JJ          DEP: conj  Description: adjective (English), other noun-modifier (Chinese)
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# now              POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# data             POS: NOUN        TAG: NN          DEP: npadvmod  Description: noun, singular or mass
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# driven           POS: ADJ         TAG: JJ          DEP: conj  Description: adjective (English), other noun-modifier (Chinese)
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# asserted         POS: VERB        TAG: VBD         DEP: conj  Description: verb, past tense
# that             POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# "                POS: PUNCT       TAG: ``          DEP: punct  Description: opening quotation mark
# everything       POS: PRON        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# about            POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# science          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# is               POS: AUX         TAG: VBZ         DEP: aux  Description: verb, 3rd person singular present
# changing         POS: VERB        TAG: VBG         DEP: ccomp  Description: verb, gerund or present participle
# because          POS: SCONJ       TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# of               POS: ADP         TAG: IN          DEP: pcomp  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# impact           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# information      POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# technology       POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# "                POS: PUNCT       TAG: ''          DEP: punct  Description: closing quotation mark
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# data             POS: NOUN        TAG: NNS         DEP: conj  Description: noun, plural
# deluge.[7][8     POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket

# %% [markdown]
# #Dependency Parsing

# %%
for token in doc:
    print(f"{token.text:12} <--{token.dep_:10}-- {token.head.text}")
# Out:
#             <--dep       -- Data
# Data         <--compound  -- science
# science      <--nsubj     -- is
# is           <--ROOT      -- is
# an           <--det       -- field[1
# interdisciplinary <--amod      -- field[1
# academic     <--amod      -- field[1
# field[1      <--attr      -- is
# ]            <--attr      -- is
# that         <--nsubj     -- uses
# uses         <--ccomp     -- is
# statistics   <--dobj      -- uses
# ,            <--punct     -- statistics
# scientific   <--amod      -- computing
# computing    <--conj      -- statistics
# ,            <--punct     -- computing
# scientific   <--amod      -- methods
# methods      <--conj      -- computing
# ,            <--punct     -- methods
# processing   <--conj      -- methods
# ,            <--punct     -- processing
# scientific   <--amod      -- visualization
# visualization <--conj      -- processing
# ,            <--punct     -- visualization
# algorithms   <--conj      -- visualization
# and          <--cc        -- algorithms
# systems      <--conj      -- algorithms
# to           <--aux       -- extract
# extract      <--xcomp     -- uses
# or           <--cc        -- extract
# extrapolate  <--conj      -- extract
# knowledge    <--dobj      -- extrapolate
# from         <--prep      -- extrapolate
# potentially  <--advmod    -- noisy
# noisy        <--amod      -- from
# ,            <--punct     -- noisy
# structured   <--conj      -- noisy
# ,            <--punct     -- structured
# or           <--cc        -- structured
# unstructured <--amod      -- science
# data.[2      <--nmod      -- science
# ]            <--punct     -- data.[2
#
#
#            <--dep       -- ]
# Data         <--compound  -- science
# science      <--nsubj     -- integrates
# also         <--advmod    -- integrates
# integrates   <--conj      -- is
# domain       <--compound  -- knowledge
# knowledge    <--dobj      -- integrates
# from         <--prep      -- knowledge
# the          <--det       -- domain
# underlying   <--amod      -- domain
# application  <--compound  -- domain
# domain       <--pobj      -- from
# (            <--punct     -- domain
# e.g.         <--dep       -- (
# ,            <--punct     -- e.g.
# natural      <--amod      -- sciences
# sciences     <--appos     -- domain
# ,            <--punct     -- sciences
# information  <--compound  -- technology
# technology   <--conj      -- sciences
# ,            <--punct     -- technology
# and          <--cc        -- technology
# medicine).[3 <--conj      -- technology
# ]            <--punct     -- integrates
# Data         <--compound  -- science
# science      <--nsubj     -- is
# is           <--ROOT      -- is
# multifaceted <--acomp     -- is
# and          <--cc        -- is
# can          <--aux       -- described
# be           <--auxpass   -- described
# described    <--conj      -- is
# as           <--prep      -- described
# a            <--det       -- science
# science      <--pobj      -- as
# ,            <--punct     -- science
# a            <--det       -- paradigm
# research     <--compound  -- paradigm
# paradigm     <--conj      -- science
# ,            <--punct     -- paradigm
# a            <--det       -- method
# research     <--compound  -- method
# method       <--conj      -- paradigm
# ,            <--punct     -- method
# a            <--det       -- discipline
# discipline   <--conj      -- method
# ,            <--punct     -- discipline
# a            <--det       -- workflow
# workflow     <--conj      -- discipline
# ,            <--punct     -- discipline
# and          <--cc        -- discipline
# a            <--det       -- science
# profession.[4 <--nmod      -- science
# ]            <--punct     -- profession.[4
#
#
#            <--dep       -- ]
# Data         <--compound  -- science
# science      <--nsubj     -- is
# is           <--conj      -- is
# "            <--punct     -- is
# a            <--det       -- concept
# concept      <--attr      -- is
# to           <--aux       -- unify
# unify        <--acl       -- concept
# statistics   <--dobj      -- unify
# ,            <--punct     -- statistics
# data         <--compound  -- analysis
# analysis     <--conj      -- statistics
# ,            <--punct     -- analysis
# informatics  <--conj      -- analysis
# ,            <--punct     -- informatics
# and          <--cc        -- informatics
# their        <--poss      -- methods
# related      <--amod      -- methods
# methods      <--conj      -- informatics
# "            <--punct     -- methods
# to           <--aux       -- understand
# "            <--punct     -- understand
# understand   <--relcl     -- concept
# and          <--cc        -- understand
# analyze      <--conj      -- understand
# actual       <--amod      -- phenomena
# phenomena    <--dobj      -- analyze
# "            <--punct     -- phenomena
# with         <--prep      -- analyze
# data.[5      <--pobj      -- with
# ]            <--punct     -- is
# It           <--nsubj     -- uses
# uses         <--ROOT      -- uses
# techniques   <--dobj      -- uses
# and          <--cc        -- techniques
# theories     <--conj      -- techniques
# drawn        <--acl       -- techniques
# from         <--prep      -- drawn
# many         <--amod      -- fields
# fields       <--pobj      -- from
# within       <--prep      -- drawn
# the          <--det       -- context
# context      <--pobj      -- within
# of           <--prep      -- context
# mathematics  <--pobj      -- of
# ,            <--punct     -- mathematics
# statistics   <--conj      -- mathematics
# ,            <--punct     -- statistics
# computer     <--compound  -- science
# science      <--conj      -- statistics
# ,            <--punct     -- science
# information  <--compound  -- science
# science      <--conj      -- science
# ,            <--punct     -- science
# and          <--cc        -- science
# domain       <--compound  -- knowledge.[6
# knowledge.[6 <--conj      -- science
# ]            <--punct     -- knowledge.[6
# However      <--advmod    -- is
# ,            <--punct     -- is
# data         <--compound  -- science
# science      <--nsubj     -- is
# is           <--ROOT      -- is
# different    <--acomp     -- is
# from         <--prep      -- different
# computer     <--compound  -- science
# science      <--pobj      -- from
# and          <--cc        -- science
# information  <--compound  -- science
# science      <--conj      -- science
# .            <--punct     -- is
# Turing       <--amod      -- winner
# Award        <--compound  -- winner
# winner       <--compound  -- Gray
# Jim          <--compound  -- Gray
# Gray         <--nsubj     -- imagined
# imagined     <--ROOT      -- imagined
# data         <--compound  -- science
# science      <--dobj      -- imagined
# as           <--prep      -- imagined
# a            <--det       -- paradigm
# "            <--punct     -- paradigm
# fourth       <--amod      -- paradigm
# paradigm     <--pobj      -- as
# "            <--punct     -- paradigm
# of           <--prep      -- paradigm
# science      <--pobj      -- of
# (            <--punct     -- science
# empirical    <--amod      -- science
# ,            <--punct     -- empirical
# theoretical  <--conj      -- empirical
# ,            <--punct     -- theoretical
# computational <--conj      -- theoretical
# ,            <--punct     -- computational
# and          <--cc        -- computational
# now          <--advmod    -- driven
# data         <--npadvmod  -- driven
# -            <--punct     -- driven
# driven       <--conj      -- computational
# )            <--punct     -- driven
# and          <--cc        -- imagined
# asserted     <--conj      -- imagined
# that         <--mark      -- changing
# "            <--punct     -- changing
# everything   <--nsubj     -- changing
# about        <--prep      -- everything
# science      <--pobj      -- about
# is           <--aux       -- changing
# changing     <--ccomp     -- asserted
# because      <--prep      -- changing
# of           <--pcomp     -- because
# the          <--det       -- impact
# impact       <--pobj      -- because
# of           <--prep      -- impact
# information  <--compound  -- technology
# technology   <--pobj      -- of
# "            <--punct     -- impact
# and          <--cc        -- impact
# the          <--det       -- data
# data         <--conj      -- impact
# deluge.[7][8 <--appos     -- data
# ]            <--punct     -- imagined

# %% [markdown]
# #Sentence wise grammar parsing

# %%
for sent in doc.sents:
    print("Sentence:", sent.text)
    for token in sent:
        print(f"  {token.text:15} {token.pos_:10} {token.dep_:10} --> {token.head.text}")
    print()
# Out:
# Sentence:
# Data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processing, scientific visualization, algorithms and systems to extract or extrapolate knowledge from potentially noisy, structured, or unstructured data.[2]
#
# Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3]
#
#                SPACE      dep        --> Data
#   Data            NOUN       compound   --> science
#   science         NOUN       nsubj      --> is
#   is              AUX        ROOT       --> is
#   an              DET        det        --> field[1
#   interdisciplinary NOUN       amod       --> field[1
#   academic        ADJ        amod       --> field[1
#   field[1         PROPN      attr       --> is
#   ]               PUNCT      attr       --> is
#   that            PRON       nsubj      --> uses
#   uses            VERB       ccomp      --> is
#   statistics      NOUN       dobj       --> uses
#   ,               PUNCT      punct      --> statistics
#   scientific      ADJ        amod       --> computing
#   computing       NOUN       conj       --> statistics
#   ,               PUNCT      punct      --> computing
#   scientific      ADJ        amod       --> methods
#   methods         NOUN       conj       --> computing
#   ,               PUNCT      punct      --> methods
#   processing      NOUN       conj       --> methods
#   ,               PUNCT      punct      --> processing
#   scientific      ADJ        amod       --> visualization
#   visualization   NOUN       conj       --> processing
#   ,               PUNCT      punct      --> visualization
#   algorithms      NOUN       conj       --> visualization
#   and             CCONJ      cc         --> algorithms
#   systems         NOUN       conj       --> algorithms
#   to              PART       aux        --> extract
#   extract         VERB       xcomp      --> uses
#   or              CCONJ      cc         --> extract
#   extrapolate     VERB       conj       --> extract
#   knowledge       NOUN       dobj       --> extrapolate
#   from            ADP        prep       --> extrapolate
#   potentially     ADV        advmod     --> noisy
#   noisy           ADJ        amod       --> from
#   ,               PUNCT      punct      --> noisy
#   structured      VERB       conj       --> noisy
#   ,               PUNCT      punct      --> structured
#   or              CCONJ      cc         --> structured
#   unstructured    ADJ        amod       --> science
#   data.[2         PROPN      nmod       --> science
#   ]               PUNCT      punct      --> data.[2
#
#
#               SPACE      dep        --> ]
#   Data            NOUN       compound   --> science
#   science         NOUN       nsubj      --> integrates
#   also            ADV        advmod     --> integrates
#   integrates      VERB       conj       --> is
#   domain          NOUN       compound   --> knowledge
#   knowledge       NOUN       dobj       --> integrates
#   from            ADP        prep       --> knowledge
#   the             DET        det        --> domain
#   underlying      VERB       amod       --> domain
#   application     NOUN       compound   --> domain
#   domain          NOUN       pobj       --> from
#   (               PUNCT      punct      --> domain
#   e.g.            ADV        dep        --> (
#   ,               PUNCT      punct      --> e.g.
#   natural         ADJ        amod       --> sciences
#   sciences        NOUN       appos      --> domain
#   ,               PUNCT      punct      --> sciences
#   information     NOUN       compound   --> technology
#   technology      NOUN       conj       --> sciences
#   ,               PUNCT      punct      --> technology
#   and             CCONJ      cc         --> technology
#   medicine).[3    PROPN      conj       --> technology
#   ]               PUNCT      punct      --> integrates
#
# Sentence: Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]
#
# Data science is "a concept to unify statistics, data analysis, informatics, and their related methods" to "understand and analyze actual phenomena" with data.[5]
#   Data            NOUN       compound   --> science
#   science         NOUN       nsubj      --> is
#   is              AUX        ROOT       --> is
#   multifaceted    ADJ        acomp      --> is
#   and             CCONJ      cc         --> is
#   can             AUX        aux        --> described
#   be              AUX        auxpass    --> described
#   described       VERB       conj       --> is
#   as              ADP        prep       --> described
#   a               DET        det        --> science
#   science         NOUN       pobj       --> as
#   ,               PUNCT      punct      --> science
#   a               DET        det        --> paradigm
#   research        NOUN       compound   --> paradigm
#   paradigm        NOUN       conj       --> science
#   ,               PUNCT      punct      --> paradigm
#   a               DET        det        --> method
#   research        NOUN       compound   --> method
#   method          NOUN       conj       --> paradigm
#   ,               PUNCT      punct      --> method
#   a               DET        det        --> discipline
#   discipline      NOUN       conj       --> method
#   ,               PUNCT      punct      --> discipline
#   a               DET        det        --> workflow
#   workflow        NOUN       conj       --> discipline
#   ,               PUNCT      punct      --> discipline
#   and             CCONJ      cc         --> discipline
#   a               DET        det        --> science
#   profession.[4   NOUN       nmod       --> science
#   ]               PUNCT      punct      --> profession.[4
#
#
#               SPACE      dep        --> ]
#   Data            NOUN       compound   --> science
#   science         NOUN       nsubj      --> is
#   is              AUX        conj       --> is
#   "               PUNCT      punct      --> is
#   a               DET        det        --> concept
#   concept         NOUN       attr       --> is
#   to              PART       aux        --> unify
#   unify           VERB       acl        --> concept
#   statistics      NOUN       dobj       --> unify
#   ,               PUNCT      punct      --> statistics
#   data            NOUN       compound   --> analysis
#   analysis        NOUN       conj       --> statistics
#   ,               PUNCT      punct      --> analysis
#   informatics     NOUN       conj       --> analysis
#   ,               PUNCT      punct      --> informatics
#   and             CCONJ      cc         --> informatics
#   their           PRON       poss       --> methods
#   related         ADJ        amod       --> methods
#   methods         NOUN       conj       --> informatics
#   "               PUNCT      punct      --> methods
#   to              PART       aux        --> understand
#   "               PUNCT      punct      --> understand
#   understand      VERB       relcl      --> concept
#   and             CCONJ      cc         --> understand
#   analyze         VERB       conj       --> understand
#   actual          ADJ        amod       --> phenomena
#   phenomena       NOUN       dobj       --> analyze
#   "               PUNCT      punct      --> phenomena
#   with            ADP        prep       --> analyze
#   data.[5         NUM        pobj       --> with
#   ]               PUNCT      punct      --> is
#
# Sentence: It uses techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, information science, and domain knowledge.[6]
#   It              PRON       nsubj      --> uses
#   uses            VERB       ROOT       --> uses
#   techniques      NOUN       dobj       --> uses
#   and             CCONJ      cc         --> techniques
#   theories        NOUN       conj       --> techniques
#   drawn           VERB       acl        --> techniques
#   from            ADP        prep       --> drawn
#   many            ADJ        amod       --> fields
#   fields          NOUN       pobj       --> from
#   within          ADP        prep       --> drawn
#   the             DET        det        --> context
#   context         NOUN       pobj       --> within
#   of              ADP        prep       --> context
#   mathematics     NOUN       pobj       --> of
#   ,               PUNCT      punct      --> mathematics
#   statistics      NOUN       conj       --> mathematics
#   ,               PUNCT      punct      --> statistics
#   computer        NOUN       compound   --> science
#   science         NOUN       conj       --> statistics
#   ,               PUNCT      punct      --> science
#   information     NOUN       compound   --> science
#   science         NOUN       conj       --> science
#   ,               PUNCT      punct      --> science
#   and             CCONJ      cc         --> science
#   domain          NOUN       compound   --> knowledge.[6
#   knowledge.[6    NOUN       conj       --> science
#   ]               PUNCT      punct      --> knowledge.[6
#
# Sentence: However, data science is different from computer science and information science.
#   However         ADV        advmod     --> is
#   ,               PUNCT      punct      --> is
#   data            NOUN       compound   --> science
#   science         NOUN       nsubj      --> is
#   is              AUX        ROOT       --> is
#   different       ADJ        acomp      --> is
#   from            ADP        prep       --> different
#   computer        NOUN       compound   --> science
#   science         NOUN       pobj       --> from
#   and             CCONJ      cc         --> science
#   information     NOUN       compound   --> science
#   science         NOUN       conj       --> science
#   .               PUNCT      punct      --> is
#
# Sentence: Turing Award winner Jim Gray imagined data science as a "fourth paradigm" of science (empirical, theoretical, computational, and now data-driven) and asserted that "everything about science is changing because of the impact of information technology" and the data deluge.[7][8]
#   Turing          VERB       amod       --> winner
#   Award           PROPN      compound   --> winner
#   winner          NOUN       compound   --> Gray
#   Jim             PROPN      compound   --> Gray
#   Gray            PROPN      nsubj      --> imagined
#   imagined        VERB       ROOT       --> imagined
#   data            NOUN       compound   --> science
#   science         NOUN       dobj       --> imagined
#   as              ADP        prep       --> imagined
#   a               DET        det        --> paradigm
#   "               PUNCT      punct      --> paradigm
#   fourth          ADJ        amod       --> paradigm
#   paradigm        NOUN       pobj       --> as
#   "               PUNCT      punct      --> paradigm
#   of              ADP        prep       --> paradigm
#   science         NOUN       pobj       --> of
#   (               PUNCT      punct      --> science
#   empirical       ADJ        amod       --> science
#   ,               PUNCT      punct      --> empirical
#   theoretical     ADJ        conj       --> empirical
#   ,               PUNCT      punct      --> theoretical
#   computational   ADJ        conj       --> theoretical
#   ,               PUNCT      punct      --> computational
#   and             CCONJ      cc         --> computational
#   now             ADV        advmod     --> driven
#   data            NOUN       npadvmod   --> driven
#   -               PUNCT      punct      --> driven
#   driven          ADJ        conj       --> computational
#   )               PUNCT      punct      --> driven
#   and             CCONJ      cc         --> imagined
#   asserted        VERB       conj       --> imagined
#   that            SCONJ      mark       --> changing
#   "               PUNCT      punct      --> changing
#   everything      PRON       nsubj      --> changing
#   about           ADP        prep       --> everything
#   science         NOUN       pobj       --> about
#   is              AUX        aux        --> changing
#   changing        VERB       ccomp      --> asserted
#   because         SCONJ      prep       --> changing
#   of              ADP        pcomp      --> because
#   the             DET        det        --> impact
#   impact          NOUN       pobj       --> because
#   of              ADP        prep       --> impact
#   information     NOUN       compound   --> technology
#   technology      NOUN       pobj       --> of
#   "               PUNCT      punct      --> impact
#   and             CCONJ      cc         --> impact
#   the             DET        det        --> data
#   data            NOUN       conj       --> impact
#   deluge.[7][8    PROPN      appos      --> data
#   ]               PUNCT      punct      --> imagined

# %% [markdown]
# #Visualization

# %%
from spacy import displacy

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9253493d05f64bdbb866efccda4ab7d9-0" class="displacy" width="30325" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Data</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">science</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">interdisciplinary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">academic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">field[1]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">uses</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">statistics,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">scientific</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">computing,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">scientific</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">methods,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">processing,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">scientific</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">visualization,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">algorithms</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">systems</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">extract</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">extrapolate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">knowledge</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">potentially</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">noisy,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">structured,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor
